# %%
from whoosh import index
from whoosh.fields import Schema, TEXT, NUMERIC
import os

# %%
import json

# %%
with open("../../data/processed/bible.json", encoding="utf-8") as f:
    bible = json.load(f)

# %%
verses = [{"text": bible[i]["text"], "index": i} for i in range(len(bible))]

# %%
# Define schema: 'title' and 'content' fields are text searchable
schema = Schema(text=TEXT(stored=True), index=NUMERIC(stored=True, unique=True))

# Create index directory if it doesn't exist
try:
    DIR = "../../data/processed/bm25"
    if not os.path.exists(DIR):
        os.mkdir(DIR)

    # Create index
    ix = index.create_in(DIR, schema)

    # Open writer to add documents
    writer = ix.writer()

    # Add some documents
    for ver in verses:
        writer.add_document(**ver)

    writer.commit()

except Exception as e:
    writer.cancel()
    print(f"Failed to write to {DIR} because {e} occur. Writer cancelled.")
